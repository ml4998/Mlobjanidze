# %% [markdown]
# # Homework 7, Part One: Lots and lots of questions about beer

# %% [markdown]
# ### Do your importing and your setup

# %%
import pandas as pd

# %% [markdown]
# ## Read in the file `craftcans.csv`, and look at the first first rows

# %%
df = pd.read_csv("craftcans.csv")

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2416 entries, 0 to 2415
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Beer      2416 non-null   object
#  1   Brewery   2410 non-null   object
#  2   Location  2410 non-null   object
#  3   Style     2405 non-null   object
#  4   Size      2410 non-null   object
#  5   ABV       2348 non-null   object
#  6   IBUs      2410 non-null   object
# dtypes: object(7)
# memory usage: 132.3+ KB

# %%
(len(df))
# Out:
# 2416

# %% [markdown]
# # Checking out our alcohol

# %% [markdown]
# ## What are the top 10 producers in terms of different cans of beer?

# %%
df.head()
# Out:
#             Beer            Brewery         Location               Style  \
# 0   Get Together  NorthGate Brewing  Minneapolis, MN        American IPA
# 1  Maggie's Leap  NorthGate Brewing  Minneapolis, MN  Milk / Sweet Stout
# 2     Wall's End  NorthGate Brewing  Minneapolis, MN   English Brown Ale
# 3        Pumpion  NorthGate Brewing  Minneapolis, MN         Pumpkin Ale
# 4     Stronghold  NorthGate Brewing  Minneapolis, MN     American Porter
#
#      Size    ABV IBUs
# 0  16 oz.  4.50%   50
# 1  16 oz.  4.90%   26
# 2  16 oz.  4.80%   19
# 3  16 oz.  6.00%   38
# 4  16 oz.  6.00%   25

# %%
df.sort_values(by='Brewery').head(10)
# Out:
#                        Beer                    Brewery  Location  \
# 1222               Pub Beer  10 Barrel Brewing Company  Bend, OR
# 581              Garce Selé        18th Street Brewery  Gary, IN
# 425           Sex and Candy        18th Street Brewery  Gary, IN
# 426            Black Exodus        18th Street Brewery  Gary, IN
# 550            Cone Crusher        18th Street Brewery  Gary, IN
# 423     Rise of the Phoenix        18th Street Brewery  Gary, IN
# 696            Bitter Bitch        18th Street Brewery  Gary, IN
# 427     Lake Street Express        18th Street Brewery  Gary, IN
# 579       Sophomoric Saison        18th Street Brewery  Gary, IN
# 580   Regional Ring Of Fire        18th Street Brewery  Gary, IN
#
#                                Style    Size    ABV            IBUs
# 1222             American Pale Lager  12 oz.  5.00%  Does not apply
# 581           Saison / Farmhouse Ale  12 oz.  6.90%  Does not apply
# 425                     American IPA  12 oz.  7.50%  Does not apply
# 426                    Oatmeal Stout  12 oz.  7.70%  Does not apply
# 550   American Double / Imperial IPA  12 oz.  8.60%  Does not apply
# 423                     American IPA  12 oz.  7.10%  Does not apply
# 696          American Pale Ale (APA)   12 oz  6.10%              60
# 427          American Pale Ale (APA)  12 oz.  4.50%  Does not apply
# 579           Saison / Farmhouse Ale  12 oz.  7.20%  Does not apply
# 580           Saison / Farmhouse Ale  12 oz.  7.30%  Does not apply

# %% [markdown]
# ## What is the most common ABV? (alcohol by volume)

# %%
df.value_counts('ABV').head(1)
# Out:
# ABV
# 5.00%    215
# Name: count, dtype: int64

# %% [markdown]
# ## Oh, weird, ABV isn't a number. Convert it to a number for me, please.
#
# It's going to take a few steps!
#
# ### First, let's just look at the ABV column by itself

# %%
str(df.ABV
# Out:
# '0       4.50%\n1       4.90%\n2       4.80%\n3       6.00%\n4       6.00%\n        ...  \n2411    5.30%\n2412    9.90%\n2413    8.00%\n2414    8.70%\n2415    6.50%\nName: ABV, Length: 2416, dtype: object'

# %% [markdown]
# ### Hm, `%` isn't part of  a number. Let's remove it.
#
# When you're confident you got it right, save the results back into the `ABV` column.
#
# - *Tip: In programming the easiest way to remove something is to *replacing it with nothing*.*
# - *Tip: "nothing" might seem like `NaN` sinc we talked about it a lot in class, but in this case it isn't! It's just an empty string, like ""*
# - *Tip: `.replace` is used for replacing ENTIRE cells, while `.str.replace` is useful for replacing PARTS of cells (see my New York example)*

# %%
#it already gave me a number so i'm not sure what to do...

# %% [markdown]
# ### Now let's turn `ABV` into a numeric data type
#
# Save the results back into the `ABV` column (again), and then check `df.dtypes` to make sure it worked.
#
# - *Tip: We used `.astype(int)` during class, but this has a decimal in it...*

# %%
df['IBUs'] = str.rstrip('%').astype('float')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 df['IBUs'] = str.rstrip('%').astype('float')
#
# AttributeError: 'str' object has no attribute 'astype'

# %%
df['IBUs'] = str.replace( )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 df['IBUs'] = str.replace( )
#
# TypeError: unbound method str.replace() needs an argument

# %% [markdown]
# ## What's the ABV of the average beer look like?
#
# ### Show me in two different ways: one command to show the `median`/`mean`/etc, and secondly show me a chart

# %%
float(df['ABV'].median())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/pandas/core/nanops.py:785, in nanmedian(values, axis, skipna, mask)
#     784 try:
# --> 785     values = values.astype("f8")
#     786 except ValueError as err:
#     787     # e.g. "could not convert string to float: 'a'"
#
# ValueError: could not convert string to float: '4.50%'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 float(df['ABV'].median())
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/pandas/core/series.py:6231, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6223 @doc(make_doc("median", ndim=1))
#    6224 def median(
#    6225     self,
#    (...)
#    6229     **kwargs,
#    6230 ):
# -> 6231     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/pandas/core/generic.py:11995, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11988 def median(
#   11989     self,
#   11990     axis: Axis | None = 0,
#    (...)
#   11993     **kwargs,
#   11994 ) -> Series | float:
# > 11995     return self._stat_function(
#   11996         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   11997     )
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/pandas/core/generic.py:11941, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11937 nv.validate_func(name, (), kwargs)
#   11939 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11941 return self._reduce(
#   11942     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11943 )
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/pandas/core/series.py:6129, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6124     # GH#47500 - change to TypeError to match other methods
#    6125     raise TypeError(
#    6126         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6127         "with non-numeric dtypes."
#    6128     )
# -> 6129 return op(delegate, skipna=skipna, **kwds)
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/pandas/core/nanops.py:788, in nanmedian(values, axis, skipna, mask)
#     785         values = values.astype("f8")
#     786     except ValueError as err:
#     787         # e.g. "could not convert string to float: 'a'"
# --> 788         raise TypeError(str(err)) from err
#     789 if mask is not None:
#     790     values[mask] = np.nan
#
# TypeError: could not convert string to float: '4.50%'

# %% [markdown]
# ### We don't have ABV for all of the beers, how many are we missing them from?
#
# - *Tip: You can use `isnull()` or `notnull()` to see where a column is missing data.*
# - *Tip: You just want to count how many `True`s and `False`s there are.*
# - *Tip: It's a weird trick involving something we usually use to count things in a column*

# %%
df['ABV'].isnull().sum()
#we use value_counts() to count things but when I use value_counts() it gives me 0...
# Out:
# 68

# %% [markdown]
# # Looking at location
#
# Brooklyn used to produce 80% of the country's beer! Let's see if it's still true.

# %% [markdown]
# ## What are the top 10 cities in the US for canned craft beer?

# %%
df.sort_values(by='Location').head(10)
# Out:
#                              Beer                           Brewery  \
# 989            Troopers Alley IPA        Wolf Hills Brewing Company
# 2072                  Abita Amber             Abita Brewing Company
# 2071                  Purple Haze             Abita Brewing Company
# 2070                  Jockamo IPA             Abita Brewing Company
# 335            Sietsema Red Label  Sietsema Orchards and Cider Mill
# 2305  Full Nelson Pale Ale (2010)             Blue Mountain Brewery
# 1118  Blue Mountain Classic Lager             Blue Mountain Brewery
# 1117             Steel Wheels ESB             Blue Mountain Brewery
# 1116         Full Nelson Pale Ale             Blue Mountain Brewery
# 1135                   Havanüther           Orlison Brewing Company
#
#                 Location                                Style    Size    ABV  \
# 989         Abingdon, VA                         American IPA  12 oz.  5.90%
# 2072   Abita Springs, LA           American Amber / Red Lager  12 oz.  4.50%
# 2071   Abita Springs, LA               Fruit / Vegetable Beer  12 oz.  4.20%
# 2070   Abita Springs, LA                         American IPA  12 oz.  6.50%
# 335              Ada, MI                                Cider  16 oz.  6.90%
# 2305           Afton, VA              American Pale Ale (APA)  12 oz.  5.90%
# 1118           Afton, VA                      Euro Pale Lager  12 oz.  5.30%
# 1117           Afton, VA  Extra Special / Strong Bitter (ESB)  12 oz.  6.50%
# 1116           Afton, VA              American Pale Ale (APA)  12 oz.  5.90%
# 1135  Airway Heights, WA                          Light Lager  16 oz.  4.10%
#
#                 IBUs
# 989              135
# 2072              17
# 2071              13
# 2070              52
# 335   Does not apply
# 2305              60
# 1118              22
# 1117              30
# 1116              60
# 1135  Does not apply

# %% [markdown]
# ## List all of the beer from Brooklyn, NY

# %%
df[df['Location'] == 'Brooklyn, NY']
# Out:
#                                  Beer              Brewery      Location  \
# 115                            4Beans  Sixpoint Craft Ales  Brooklyn, NY
# 210                            Jammer  Sixpoint Craft Ales  Brooklyn, NY
# 246                           Abigale  Sixpoint Craft Ales  Brooklyn, NY
# 404                     Nomader Weiss    Evil Twin Brewing  Brooklyn, NY
# 421                               Rad  Sixpoint Craft Ales  Brooklyn, NY
# 439                      Molotov Lite    Evil Twin Brewing  Brooklyn, NY
# 588                           Bengali  Sixpoint Craft Ales  Brooklyn, NY
# 713                     Sensi Harvest  Sixpoint Craft Ales  Brooklyn, NY
# 969                            Hi-Res  Sixpoint Craft Ales  Brooklyn, NY
# 987             KelSo Nut Brown Lager   KelSo Beer Company  Brooklyn, NY
# 1057                    Global Warmer  Sixpoint Craft Ales  Brooklyn, NY
# 1074               Autumnation (2013)  Sixpoint Craft Ales  Brooklyn, NY
# 1366                    American IPA             12 oz.   2.70%
# 1373    English India Pale Ale (IPA)             16 oz.   6.80%
# 1624                   Baltic Porter             12 oz.   9.90%
# 1836              American Brown Ale             16 oz.   5.90%
# 1857           English Pale Mild Ale             12 oz.   4.50%
# 1962         American Pale Ale (APA)             12 oz.   5.50%
# 1970         American Pale Wheat Ale             16 oz.   5.20%
# 1971          Saison / Farmhouse Ale             16 oz.   4.90%
# 1972  American Double / Imperial IPA             12 oz.   9.10%
# 2027    English India Pale Ale (IPA)             12 oz.   6.80%
# 2062                  American Stout             16 oz.   6.30%
# 2074                     Pumpkin Ale             16 oz.   6.00%
# 2140                 German Pilsener             16 oz.   5.40%
# 2141                       Cream Ale             16 oz.   5.20%
# 2142                        Rye Beer             16 oz.   6.30%
# 2143                    American IPA             16 oz.   6.40%
# 2219           English Pale Mild Ale             12 oz.   4.50%
# 2350      American Amber / Red Lager             16 oz.   5.20%
# 2351      American Amber / Red Lager             12 oz.   5.20%
#
#                 IBUs
# 115               52
# 210               16
# 246   Does not apply
# 404   Does not apply
# 421                7
# 439   Does not apply
# 588               62
# 713               50
# 969              111
# 987               19
# 1057              70
# 1074              74
# 1093              64
# 1267              42
# 1268              34
# 1269              57
# 1270              62
# 1305              23
# 1365  Does not apply
# 1366  Does not apply
# 1373              47
# 1624              85
# 1836              47
# 1857  Does not apply
# 1962  Does not apply
# 1970              11
# 1971              35
# 1972             103
# 2027              47
# 2062              69
# 2074              48
# 2140              42
# 2141              34
# 2142              57
# 2143              62
# 2219  Does not apply
# 2350  Does not apply
# 2351  Does not apply

# %% [markdown]
# ## What brewery in Brooklyn puts out the most different cans of beer?

# %%
df[df['Location'] == 'Brooklyn, NY'].sort_values(by='Style')
# Out:
#                                  Beer              Brewery      Location  \
# 2351          Brooklyn Lager (12 oz.)     Brooklyn Brewery  Brooklyn, NY
# 2350          Brooklyn Lager (16 oz.)     Brooklyn Brewery  Brooklyn, NY
# 1836                       Brownstone  Sixpoint Craft Ales  Brooklyn, NY
# 1972                            Resin  Sixpoint Craft Ales  Brooklyn, NY
# 439                      Molotov Lite    Evil Twin Brewing  Brooklyn, NY
# 969                            Hi-Res  Sixpoint Craft Ales  Brooklyn, NY
# 2143             Bengali Tiger (2011)  Sixpoint Craft Ales  Brooklyn, NY
# 588                           Bengali  Sixpoint Craft Ales  Brooklyn, NY
# 1366                      Bikini Beer    Evil Twin Brewing  Brooklyn, NY
# 1270                    Bengali Tiger  Sixpoint Craft Ales  Brooklyn, NY
# 1074               Autumnation (2013)  Sixpoint Craft Ales  Brooklyn, NY
# 1093             KelSo India Pale Ale   KelSo Beer Company  Brooklyn, NY
# 1962  Hipster Ale (Westbrook Brewing)    Evil Twin Brewing  Brooklyn, NY
# 1365  Hipster Ale (Two Roads Brewing)    Evil Twin Brewing  Brooklyn, NY
# 713                     Sensi Harvest  Sixpoint Craft Ales  Brooklyn, NY
# 1970                           Apollo  Sixpoint Craft Ales  Brooklyn, NY
# 2027    English India Pale Ale (IPA)             12 oz.   6.80%
# 1857           English Pale Mild Ale             12 oz.   4.50%
# 2219           English Pale Mild Ale             12 oz.   4.50%
# 987                  Euro Dark Lager             12 oz.   5.70%
# 421           Fruit / Vegetable Beer             16 oz.   3.20%
# 2140                 German Pilsener             16 oz.   5.40%
# 1267                 German Pilsener             16 oz.   5.40%
# 210                             Gose    12 oz. Slimline   4.20%
# 2074                     Pumpkin Ale             16 oz.   6.00%
# 1269                        Rye Beer             16 oz.   6.30%
# 2142                        Rye Beer             16 oz.   6.30%
# 1971          Saison / Farmhouse Ale             16 oz.   4.90%
#
#                 IBUs
# 2351  Does not apply
# 2350  Does not apply
# 1836              47
# 1972             103
# 439   Does not apply
# 969              111
# 2143              62
# 588               62
# 1366  Does not apply
# 1270              62
# 1074              74
# 1093              64
# 1962  Does not apply
# 1365  Does not apply
# 713               50
# 1970              11
# 2062              69
# 1057              70
# 1624              85
# 115               52
# 246   Does not apply
# 404   Does not apply
# 1268              34
# 2141              34
# 1305              23
# 1373              47
# 2027              47
# 1857  Does not apply
# 2219  Does not apply
# 987               19
# 421                7
# 2140              42
# 1267              42
# 210               16
# 2074              48
# 1269              57
# 2142              57
# 1971              35

# %% [markdown]
# ## What are the five most common styles of beer produced by Sixpoint?

# %%
df[df['Brewery'] == 'Sixpoint Craft Ales'].Style.value_counts().head(5)
# Out:
# Style
# American IPA                      4
# Baltic Porter                     2
# American Double / Imperial IPA    2
# German Pilsener                   2
# Cream Ale                         2
# Name: count, dtype: int64

# %% [markdown]
# ## List all of the breweries in New York state.
#
# - *Tip: We want to match *part* of the `Location` column, but not all of it.*
# - *Tip: Watch out for `NaN` values! You might be close, but you'll need to pass an extra parameter to make it work without an error.*

# %%
df.head()
# Out:
#             Beer            Brewery         Location               Style  \
# 0   Get Together  NorthGate Brewing  Minneapolis, MN        American IPA
# 1  Maggie's Leap  NorthGate Brewing  Minneapolis, MN  Milk / Sweet Stout
# 2     Wall's End  NorthGate Brewing  Minneapolis, MN   English Brown Ale
# 3        Pumpion  NorthGate Brewing  Minneapolis, MN         Pumpkin Ale
# 4     Stronghold  NorthGate Brewing  Minneapolis, MN     American Porter
#
#      Size    ABV IBUs
# 0  16 oz.  4.50%   50
# 1  16 oz.  4.90%   26
# 2  16 oz.  4.80%   19
# 3  16 oz.  6.00%   38
# 4  16 oz.  6.00%   25

# %%
df[df['Location'].str.contains('NY', na=False)]['Brewery'].unique()
# Out:
# array(['Sixpoint Craft Ales', 'Evil Twin Brewing', 'Chatham Brewing',
#        'Newburgh Brewing Company', 'Southampton Publick House',
#        'Montauk Brewing Company', 'Matt Brewing Company',
#        'The Bronx Brewery', 'KelSo Beer Company', 'Brooklyn Brewery',
#        'The Manhattan Brewing Company', 'Blue Point Brewing Company',
#        'Bomb Beer Company', 'Dundee Brewing Company',
#        'Upstate Brewing Company', 'Butternuts Beer and Ale'], dtype=object)

# %% [markdown]
# ### Now *count* all of the breweries in New York state

# %%
df[df['Location'].str.contains('NY', na=False)]['Brewery'].value_counts()
# Out:
# Brewery
# Sixpoint Craft Ales              24
# Matt Brewing Company             13
# Brooklyn Brewery                  6
# Evil Twin Brewing                 5
# Blue Point Brewing Company        4
# Butternuts Beer and Ale           4
# The Bronx Brewery                 3
# KelSo Beer Company                3
# Chatham Brewing                   2
# Montauk Brewing Company           2
# Bomb Beer Company                 2
# Upstate Brewing Company           2
# Newburgh Brewing Company          1
# Southampton Publick House         1
# The Manhattan Brewing Company     1
# Dundee Brewing Company            1
# Name: count, dtype: int64

# %% [markdown]
# # Measuring International Bitterness Units
#
# ## Display all of the IPAs
#
# Include American IPAs, Imperial IPAs, and anything else with "IPA in it."
#
# IPA stands for [India Pale Ale](https://www.bonappetit.com/story/ipa-beer-styles), and is probably the most popular kind of beer in the US for people who are drinking [craft beer](https://www.craftbeer.com/beer/what-is-craft-beer).

# %%
df[df['Style'] == 'American IPA']
# Out:
#                        Beer                    Brewery             Location  \
# 0              Get Together          NorthGate Brewing      Minneapolis, MN
# 17             Pile of Face  Against the Grain Brewery       Louisville, KY
# 25                    Solis  Mike Hess Brewing Company        San Diego, CA
# 33                 Villager    Fort Point Beer Company    San Francisco, CA
# 38                   HopArt      COAST Brewing Company       Charleston, SC
# ...                     ...                        ...                  ...
# 2382            Caldera IPA    Caldera Brewing Company          Ashland, OR
# 2387          Big Swell IPA       Maui Brewing Company          Lahaina, HI
# 2394                113 IPA    Sly Fox Brewing Company        Pottstown, PA
# 2406                Furious      Surly Brewing Company  Brooklyn Center, MN
# 2408  Brew Free! or Die IPA     21st Amendment Brewery    San Francisco, CA
#
#              Style    Size    ABV            IBUs
# 0     American IPA  16 oz.  4.50%              50
# 17    American IPA  16 oz.  6.00%              65
# 25    American IPA  16 oz.  7.50%              85
# 33    American IPA  12 oz.  6.30%              42
# 38    American IPA  16 oz.  7.70%  Does not apply
# ...            ...     ...    ...             ...
# 2382  American IPA  12 oz.  6.10%              94
# 2387  American IPA  12 oz.  6.20%              65
# 2394  American IPA  12 oz.  7.00%             113
# 2406  American IPA  16 oz.  6.20%              99
# 2408  American IPA  12 oz.  7.00%              65
#
# [424 rows x 7 columns]

# %%
# Out:
# Empty DataFrame
# Columns: [Beer, Brewery, Location, Style, Size, ABV, IBUs]
# Index: []

# %% [markdown]
# IPAs are usually pretty hoppy and bitter. IBU stands for [International Bitterness Unit](http://www.thebrewenthusiast.com/ibus/), and while a lot of places like to brag about having the most bitter beer (it's an American thing!), IBUs don't necessary *mean anything*.
#
# Let's look at how different beers have different IBU measurements.

# %% [markdown]
# ## Try to get the average IBU measurement across all beers

# %%
df['IBUs'] = pd.to_numeric(df['IBUs'], errors='coerce')

# %%
df['IBUs'].mean()
#I wasn't sure where I was supposed to put na_values
# Out:
# 42.71316725978647

# %% [markdown]
# ### Oh no, it doesn't work!
#
# It looks like some of those values *aren't numbers*. There are two ways to fix this:
#
# - *Tip: If you use [`na_values`](http://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.read_csv.html). be sure to go add it up top and run all of your cells again. You can also use `.replace` but I don't think that's as good of an idea.*
# - *Tip: Make sure you're giving `na_values` a LIST, not just a string*
#
# ### Now try to get the average IBUs again

# %% [markdown]
# ## Draw the distribution of IBU measurements, but with *twenty* bins instead of the default of 10
#
# - *Tip: Every time I ask for a distribution, I'm looking for a histogram*
# - *Tip: Use the `?` to get all of the options for building a histogram*
# - *Tip: Make sure your `matplotlib` thing is set up right!*

# %%
df["IBUs"].sort_values().head(20).hist()
# Out:
# <Axes: >

# %%
#I'm not sure what 20 bins means? So I just took the first 20 items

# %% [markdown]
# ## Hm, Interesting distribution. List all of the beers with IBUs above the 75th percentile
#
# - *Tip: There's a single that gives you the 25/50/75th percentile*
# - *Tip: You can just manually type the number when you list those beers*

# %%
int(df['IBUs'].quantile(0.75))
# Out:
# 64

# %% [markdown]
# ## List all of the beers with IBUs below the 25th percentile

# %%
int(df['IBUs'].quantile(0.25))
# Out:
# 21

# %% [markdown]
# ## List the median IBUs of each type of beer. Graph it.
#
# Put the highest at the top, and the missing ones at the bottom.
#
# - Tip: Look at the options for `sort_values` to figure out the `NaN` thing. The `?` probably won't help you here.

# %%
df.groupby('Style')['IBUs'].median()
# Out:
# Style
# Abbey Single Ale              22.0
# Altbier                       36.5
# American Adjunct Lager         9.0
# American Amber / Red Ale      31.0
# American Amber / Red Lager    23.0
#                               ...
# Tripel                        27.5
# Vienna Lager                  23.5
# Wheat Ale                     24.0
# Winter Warmer                 22.0
# Witbier                       15.5
# Name: IBUs, Length: 99, dtype: float64

# %%
df.groupby('Style')['IBUs'].median().plot()
# Out:
# <Axes: xlabel='Style'>

# %% [markdown]
# ## Hmmmm, it looks like they are generally different styles. What are the most common 5 styles of high-IBU beer vs. low-IBU beer?
#
# - *Tip: You'll want to think about it in three pieces - filtering to only find the specific beers beers, then finding out what the most common styles are, then getting the top 5.*
# - *Tip: You CANNOT do this in one command. It's going to be one command for the high and one for the low.*
# - *Tip: "High IBU" means higher than 75th percentile, "Low IBU" is under 25th percentile*

# %% [markdown]
# ## Get the average IBU of "Witbier", "Hefeweizen" and "American Pale Wheat Ale" styles
#
# I'm counting these as wheat beers. If you see any other wheat beer categories, feel free to include them. I want ONE measurement and ONE graph, not three separate ones. And 20 to 30 bins in the histogram, please.
#
# - *Tip: I hope that `isin` is in your toolbox*

# %% [markdown]
# ## Draw a histogram of the IBUs of those beers

# %% [markdown]
# ## Get the average IBU of any style with "IPA" in it (also draw a histogram)

# %% [markdown]
# ## Plot those two histograms in the same cell!
#
# I swear the behavior of this changes every year. Does it make two charts? Does it overlap them in one?

# %% [markdown]
# ## Compare the ABV of wheat beers vs. IPAs : their IBUs were really different, but how about their alcohol percentage?
#
# Wheat beers might include witbier, hefeweizen, American Pale Wheat Ale, and anything else you think is wheaty. IPAs probably have "IPA" in their name.

# %% [markdown]
# ## Good work!
